# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
reward = np.load('/Users/matte/Documents/GitHub/SAS_RL/SAS_RL/Experiments/SF_Map/SAS_NAC/Test_runp_02/0/Results/rewards.npy')
reward_rm = np.load('/Users/matte/Documents/GitHub/SAS_RL/SAS_RL/Experiments/SF_Map/SAS_NAC/Test_runp_02/0/Results/rewards_rm.npy')

# %%
plt.plot(reward)

# %%
plt.plot(reward_rm)
